# %%
import pandas as pd

# %%
riders = pd.read_csv('../data/TDF_Riders_History.csv')
stages = pd.read_csv('../data/TDF_Stages_History.csv')

# %%
# Select the field Year == 2024 in riders
riders[riders['Year'] == 2024]
# Out:
#        Unnamed: 0  Rank                    Rider  Rider No.  \
# 9878         9878     1            TADEJ POGAČAR         11
# 9879         9879     2  JONAS VINGEGAARD HANSEN          1
# 9880         9880     3          REMCO EVENEPOEL         71
# 9881         9881     4             JOAO ALMEIDA         12
# 9882         9882     5        MIKEL LANDA MEANA         74
# ...           ...   ...                      ...        ...
# 10014       10014   137             LUCA MOZZATO        167
# 10015       10015   138                 CEES BOL        193
# 10016       10016   139    JARRAD ERIKS DRIZNERS        124
# 10017       10017   140         DAVIDE BALLERINI        192
# 10018       10018   141           MARK CAVENDISH        191
#
#                             Team         Times             Gap    B         P  \
# 9878           UAE TEAM EMIRATES  83h 38' 56''               -  12'       NaN
# 9879   TEAM VISMA | LEASE A BIKE  83h 45' 13''  + 00h 06' 17''  38'       NaN
# ...

# %%
stages
# Out:
#       Unnamed: 0  Year  TotalTDFDistance  \
# 0              0  1903              2428
# 1              1  1903              2428
# 2              2  1903              2428
# 3              3  1903              2428
# 4              4  1903              2428
# ...          ...   ...               ...
# 2381        2381  2024              3492
# 2382        2382  2024              3492
# 2383        2383  2024              3492
# 2384        2384  2024              3492
# 2385        2385  2024              3492
#
#                                                   Stage
# 0                                Stage 1 : Paris > Lyon
# 1                            Stage 2 : Lyon > Marseille
# 2                        Stage 3 : Marseille > Toulouse
# 3                         Stage 4 : Toulouse > Bordeaux
# 4                           Stage 5 : Bordeaux > Nantes
# ...                                                 ...
# 2381   Stage 5 : Saint-Jean-de-Maurienne > Saint-Vulbas
# ...
