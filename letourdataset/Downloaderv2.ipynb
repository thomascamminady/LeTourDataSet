# %%
import requests
from bs4 import BeautifulSoup
from requests_html import AsyncHTMLSession
# Function to get the HTML content of a page
def get_html(url):
    response = requests.get(url)
    response.raise_for_status()
    return response.content
BASE_URL = "https://www.letour.fr"

# %%
def get_years_urls(base_url):
    # Get the HTML content
    html = get_html(base_url)
    soup = BeautifulSoup(html, 'html.parser')

    # Find the year selection element
    year_select = soup.find('select', {'name': 'year'})

    # Extract all year options
    years_urls = {option['data-tabs-target'] : BASE_URL+option['value'] for option in year_select.find_all('option') if option['value']}
    
    return years_urls

# URL of the Tour de France history page
url = "https://www.letour.fr/en/history"
years_urls = get_years_urls(url)
print(years_urls)
# Out:
# {'2023': 'https://www.letour.fr/en/block/history/11823/4e4949d130f21278f7d8bce32a071d67', '2022': 'https://www.letour.fr/en/block/history/11822/ca646e1b4b99d7ee973c457c87392395', '2021': 'https://www.letour.fr/en/block/history/11821/a3fe7d350ef546e3c27ae83a84fa3a0b', '2020': 'https://www.letour.fr/en/block/history/11820/17fa8e795e69e9f326ea26cf9912e571', '2019': 'https://www.letour.fr/en/block/history/11819/96c0eb3fa403ebf222f28b6e45115c56', '2018': 'https://www.letour.fr/en/block/history/11818/f34c3404d95a697dcf77d4cd8e8278fa', '2017': 'https://www.letour.fr/en/block/history/10810/7035a5dc53631209d3581f64a433b10d', '2016': 'https://www.letour.fr/en/block/history/10809/7be3a459d846b4672915c576cb7ed6b9', '2015': 'https://www.letour.fr/en/block/history/10808/3f166bedb535ee9bff2fb7ead0a7812c', '2014': 'https://www.letour.fr/en/block/history/10807/d538a7fbdfc0d657fbf064561840fbb1', '2013': 'https://www.letour.fr/en/block/history/10806/196e36cfe7aff4b5fc2d1055f7dcf864', '2012': 'https://www.letour.fr/en/block/history/10805/1ec24b4375d16b922c9c9c489d25465c', '2011': 'https://www.letour.fr/en/block/history/10804/89b36b01ffe439e016ec1d59c57b63d1', '2010': 'https://www.letour.fr/en/block/history/10803/757e8e81b7183fde7329fd8ab9b69783', '2009': 'https://www.letour.fr/en/block/history/10802/814bff61212e58cf7c2beaddb1c083b3', '2008': 'https://www.letour.fr/en/block/history/10801/7c59f5199df3e8a97888b3ab3deafadb', '2007': 'https://www.letour.fr/en/block/history/10800/14026271ed58df742b5e2182adc964cb', '2006': 'https://www.letour.fr/en/block/history/10799/4df09e2d455b3d4bfea3d78091f0b0b1', '2005': 'https://www.letour.fr/en/block/history/10798/dc1ea3d295e447e632d63c31d313e22c', '2004': 'https://www.letour.fr/en/block/history/10797/4c6e179ada14b5ea99feaa75cfc5cc27', '2003': 'https://www.letour.fr/en/block/history/10796/a0c4bbd9f74d2fb237f3fcfd985dcdfe', '2002': 'https://www.letour.fr/en/block/history/10795/0ed86366456d46e1defebebcedef4404', '2001': 'https://www.letour.fr/en/block/history/10794/f456958e5bf979def96740c09a39f0d0', '2000': 'https://www.letour.fr/en/block/history/10793/532062cd8f6afe8ec3796beeee9fb60d', '1999': 'https://www.letour.fr/en/block/history/10792/f892bbc452142340a7dfe883719d7637', '1998': 'https://www.letour.fr/en/block/history/10791/70c111aba67f7f32344852fc369f445d', '1997': 'https://www.letour.fr/en/block/history/10790/ba6803b7f72483da9dcef054d3564bef', '1996': 'https://www.letour.fr/en/block/history/10789/0073016ba550a84a666f752c64bafef8', '1995': 'https://www.letour.fr/en/block/history/10788/d98288396c5dbd8446699ad88413632b', '1994': 'https://www.letour.fr/en/block/history/10787/1a04d3c53ae89dcdf73df8027654c1db', '1993': 'https://www.letour.fr/en/block/history/10786/97ba8b33489f910f7217ee3f6bdd68c7', '1992': 'https://www.letour.fr/en/block/history/10785/88ea8997b2d00f171d74fdd18200c4ac', '1991': 'https://www.letour.fr/en/block/history/10784/840372b1c5ef49ced963d12709d2bfe1', '1990': 'https://www.letour.fr/en/block/history/10783/0d7fef284362baf0738e2569898bcc5c', '1989': 'https://www.letour.fr/en/block/history/10782/c5cd539d3aed4897b7a087c06fff4e5e', '1988': 'https://www.letour.fr/en/block/history/10781/39d1113fcd9febaf891760301f41a383', '1987': 'https://www.letour.fr/en/block/history/10780/fce0b5e49551473911dadd219da7cb6c', '1986': 'https://www.letour.fr/en/block/history/10779/db843b1682239241b56010705153d657', '1985': 'https://www.letour.fr/en/block/history/10778/8845310ec3c8145620ac465f3e112cca', '1984': 'https://www.letour.fr/en/block/history/10777/f1773d9b0704ed89afad4012905ec744', '1983': 'https://www.letour.fr/en/block/history/10776/1d486875bf13f11f37a63ee3a773ccc9', '1982': 'https://www.letour.fr/en/block/history/10775/6365159573723beb801f343a6efb4763', '1981': 'https://www.letour.fr/en/block/history/10774/5a2702b95bc1f297980241915b0c0eee', '1980': 'https://www.letour.fr/en/block/history/10773/ad0e4cf5a083a40d11bb15d1404559ed', '1979': 'https://www.letour.fr/en/block/history/10772/3108137894d31c631408c1e2ac551 ...

# %%
async def fetch_yearly_tdf_data(year_url):
    try:
        # Create an asynchronous HTML Session
        session = AsyncHTMLSession()
        
        # Get the HTML content
        response = await session.get(year_url)
        
        # Render the page (this will execute the JavaScript)
        await response.html.arender(timeout=20)
        
        # Parse the rendered HTML with BeautifulSoup
        soup = BeautifulSoup(response.html.html, 'html.parser')
        
        # Find the buttons with class 'tabs__item btn js-tabs-nested'
        buttons = soup.find_all('button', class_='tabs__item btn js-tabs-nested')
        
        # Extract the button details
        selections_urls = {}
        for button in buttons:
            selections_urls[button.get_text(strip=True)] = BASE_URL+button.get('data-tabs-ajax')
        
        return selections_urls
        
    except Exception as e:
        print(f"An error occurred: {e}")

selections_urls = {}
for year, url in years_urls.items():
    selections_urls[year] = await fetch_yearly_tdf_data(url)

# %%
# Function to get stages and ranking types for a given year
def get_year_data(year_url):
    """
    Gets:
    - Stages
    - Rankings
    - Distance
    """
    year_html = get_html(year_url)
    year_soup = BeautifulSoup(year_html, 'html.parser')
    
    # Get stage names
    stage_select = year_soup.find('select', {'name': 'stage'})
    stages = [option.text for option in stage_select.find_all('option') if option['value']]
    
    # Get final blobal ranking (table with class 'rankingTable' and columns 'Rank', 'Rider', 'Team', 'Times', 'Gap', 'B', 'P')
    ranking_table = year_soup.find('table', {'class': 'rankingTable'})
    rows = ranking_table.find_all('tr')
    rankings = []
    for row in rows[1:]:
        cols = row.find_all('td')
        ranking = {
            'Rank': cols[0].text.strip(),
            'Rider': cols[1].text.strip(),
            'Team': cols[2].text.strip(),
            'Times': cols[3].text.strip(),
            'Gap': cols[4].text.strip(),
            'Bonus': cols[5].text.strip(),
            'Penalty': cols[6].text.strip()
        }
        rankings.append(ranking)
    
    # Get the distance of the Tour (spans of class 'statsInfos__label' or 'statsInfos__number')
    span_text = year_soup.find_all('span', {'class': 'statsInfos__label'})
    span_value = year_soup.find_all('span', {'class': 'statsInfos__number'})
    spans = [val.text for pair in zip(span_text, span_value) for val in pair] 
    numbers = [span for span in spans]
    print(numbers)

    return stages, rankings

# Example: Get data for 2023
stages, rankings = get_year_data(years_urls["2022"])
print("Stages:", stages)
print("Rankings:", rankings)
# Out:
# ['Number of stages', '22', 'Distance (km)', '3 328']
# Stages: ['Stage 1 : Copenhague > Copenhague', 'Stage 2 : Roskilde > Nyborg', 'Stage 3 : Vejle > Sønderborg', 'Stage 1 : Transfert > Transfert', 'Stage 4 : Dunkerque > Calais', 'Stage 5 : Lille Métropole > Arenberg Porte du Hainaut', 'Stage 6 : Binche > Longwy', 'Stage 7 : Tomblaine > La Super Planche des Belles Filles', 'Stage 8 : Dole > Lausanne', 'Stage 9 : Aigle > Châtel Les Portes du Soleil', 'Stage 10 : Morzine Les Portes du Soleil > Megève', 'Stage 11 : Albertville > Col du Granon Serre Chevalier', "Stage 12 : Briançon > Alpe d'Huez", "Stage 13 : Le Bourg d'Oisans > Saint-Étienne", 'Stage 14 : Saint-Étienne > Mende', 'Stage 15 : Rodez > Carcassonne', 'Stage 16 : Carcassonne > Foix', 'Stage 17 : Saint-Gaudens > Peyragudes', 'Stage 18 : Lourdes > Hautacam', 'Stage 19 : Castelnau-Magnoac > Cahors', 'Stage 20 : Lacapelle-Marival > Rocamadour', 'Stage 21 : Paris La Défense Arena > Paris Champs-Élysées']
# Rankings: [{'Rank': '1', 'Rider': 'JONAS VINGEGAARD HANSEN', 'Team': 'JUMBO - VISMA', 'Times': "79h 33' 20''", 'Gap': '-', 'Bonus': "32'", 'Penalty': ''}, {'Rank': '2', 'Rider': 'TADEJ POGAČAR', 'Team': 'UAE TEAM EMIRATES', 'Times': "79h 36' 03''", 'Gap': "+ 00h 02' 43''", 'Bonus': "40'", 'Penalty': ''}, {'Rank': '3', 'Rider': 'GERAINT THOMAS', 'Team': 'INEOS GRENADIERS', 'Times': "79h 40' 42''", 'Gap': "+ 00h 07' 22''", 'Bonus': '', 'Penalty': ''}, {'Rank': '4', 'Rider': 'DAVID GAUDU', 'Team': 'GROUPAMA - FDJ', 'Times': "79h 46' 59''", 'Gap': "+ 00h 13' 39''", 'Bonus': "04'", 'Penalty': ''}, {'Rank': '5', 'Rider': 'ALEKSANDR VLASOV', 'Team': 'BORA - HANSGROHE', 'Times': "79h 49' 06''", 'Gap': "+ 00h 15' 46''", 'Bonus': '', 'Penalty': ''}, {'Rank': '6', 'Rider': 'NAIRO QUINTANA', 'Team': 'TEAM ARKEA - SAMSIC', 'Times': "79h 49' 53''", 'Gap': "+ 00h 16' 33''", 'Bonus': "06'", 'Penalty': "00' 10''"}, {'Rank': '7', 'Rider': 'ROMAIN BARDET', 'Team': 'TEAM DSM', 'Times': "79h 51' 31''", 'Gap': "+ 00h 18' 11''", 'Bonus': "04'", 'Penalty': ''}, {'Rank': '8', 'Rider': 'LOUIS MEINTJES', 'Team': 'INTERMARCHE - WANTY - GOBERT MATERIAUX', 'Times': "79h 52' 04''", 'Gap': "+ 00h 18' 44''", 'Bonus': "06'", 'Penalty': ''}, {'Rank': '9', 'Rider': 'ALEXEY LUTSENKO', 'Team': 'ASTANA - QAZAQSTAN TEAM', 'Times': "79h 56' 16''", 'Gap': "+ 00h 22' 56''", 'Bonus': '', 'Penalty': "00' 20''"}, {'Rank': '10', 'Rider': 'ADAM YATES', 'Team': 'INEOS GRENADIERS', 'Times': "79h 58' 12''", 'Gap': "+ 00h 24' 52''", 'Bonus': '', 'Penalty': ''}, {'Rank': '11', 'Rider': 'VALENTIN MADOUAS', 'Team': 'GROUPAMA - FDJ', 'Times': "80h 09' 19''", 'Gap': "+ 00h 35' 59''", 'Bonus': "06'", 'Penalty': ''}, {'Rank': '12', 'Rider': 'BOB JUNGELS', 'Team': 'AG2R CITROEN TEAM', 'Times': "80h 18' 43''", 'Gap': "+ 00h 45' 23''", 'Bonus': "10'", 'Penalty': ''}, {'Rank': '13', 'Rider': 'NEILSON POWLESS', 'Team': 'EF EDUCATION - EASYPOST', 'Times': "80h 20' 17''", 'Gap': "+ 00h 46' 57''", 'Bonus': '', 'Penalty': ''}, {'Rank': '14', 'Rider': 'LUIS LEON SANCHEZ', 'Team': 'BAHRAIN VICTORIOUS', 'Times': "80h 22' 38''", 'Gap': "+ 00h 49' 18''", 'Bonus': "04'", 'Penalty': ''}, {'Rank': '15', 'Rider': 'THIBAUT PINOT', 'Team': 'GROUPAMA - FDJ', 'Times': "80h 23' 45''", 'Gap': "+ 00h 50' 25''", 'Bonus': "04'", 'Penalty': ''}, {'Rank': '16', 'Rider': 'PATRICK KONRAD', 'Team': 'BORA - HANSGROHE', 'Times': "80h 30' 14''", 'Gap': "+ 00h 56' 54''", 'Bonus': '', 'Penalty': ''}, {'Rank': '17', 'Rider': 'TOM PIDCOCK', 'Team': 'INEOS GRENADIERS', 'Times': "80h 34' 35''", 'Gap': "+ 01h 01' 15''", 'Bonus': "10'", 'Penalty': ''}, {'Rank': '18', 'Rider': 'SEPP KUSS', 'Team': 'JUMBO - VISMA', 'Times': "80h 35' 49''", 'Gap': "+ 01h 02' 29''", 'Bonus': '', 'Penalty': ''}, {'Rank': '19', 'Rider': 'DYLAN TEUNS', 'Team': 'BAHRAIN VICTORIOUS', 'Times': "80h 44' 50''", 'Gap': "+ 01h 11' 30''", 'Bonus': '', 'Penalty': ''}, {'Rank': '20', 'Rider': 'BRANDON MCNULTY', 'Team': 'UAE TEAM EMIRATES', 'Times': "81h 04' 39''", 'Gap': "+ 01h 31' 19''", 'Bonus': "04'", 'Penalty': ''}, {'Rank': '21', 'Rider': 'MATTEO JORGENSON', 'Team': 'MOVISTAR TEAM', 'Times': "81h 07' 17''", 'Gap': "+ 01h 33' 57''", 'Bonus': '', 'Penalty': ''}, {'Rank': '22', 'Rider': 'WOUT VAN AERT', 'Team': 'JUMBO - VISMA', 'Times': "81h 09' 15''", 'Gap': "+ 01h 35' 55''", 'Bonus': "42'", 'Penalty': ''}, {'Rank': '23', 'Rider': 'NICHOLAS SCHULTZ', 'Team': 'TEAM BIKEEXCHANGE-JAYCO', 'Times': "81h 13' 01''", 'Gap': "+ 01h 39' 41''", 'Bonus': "06'", 'Penalty': ''}, {'Rank': '24', 'Rider': 'HUGO HOULE', 'Team': 'ISRAEL-PREMIER TECH', 'Times': "81h 15' 34''", 'Gap': "+ 01h 42' 14''", 'Bonus': "14'", 'Penalty': ''}, {'Rank': '25', 'Rider': 'BAUKE MOLLEMA', 'Team': 'TREK - SEGAFREDO', 'Times': "81h 19' 17''", 'Gap': "+ 01h 45' 57''", 'Bonus': '', 'Penalty': ''}, {'Rank': '26', 'Rider': 'RIGOBERTO URAN', 'Team': 'EF EDUCATION - EASYPOST', 'Times': "81h 21' 38''", 'Gap': "+ 01h 48' 18''", 'Bonus': '', 'Penalty': ''}, {'Rank': '27', 'Rider': 'CARLOS VERONA QUINTAN ...

# %%
def get_teams_data(team_url):
    team_html = get_html(team_url)
    team_soup = BeautifulSoup(team_html, 'html.parser')
    
    # Extract the team and riders information
    teams = team_soup.find_all('h3', class_='list__heading')
    res = {}
    for team in teams:
        team_name = team.find('a').get_text(strip=True)
        res[team_name] = []
        
        # Find the corresponding list box for the team
        list_box = team.find_next('div', class_='list__box')
        
        # Extract rider information from the list box
        riders = list_box.find_all('li', class_='list__box__item')
        for rider in riders:
            bib = rider.find('span', class_='bib').get_text(strip=True)
            name = rider.find('a', class_='runner__link').get_text(strip=True)
            res[team_name].append({'bib': bib, 'name': name})

    return res

def get_stages_data(data_url):
    data_html = get_html(data_url)
    data_soup = BeautifulSoup(data_html, 'html.parser')
    
    # Tha data here is a table with columns Stages 	Highlights 	Date 	Start 	Finish
    # Get the table with class 'rankingTable'
    table = data_soup.find('table', class_='rankingTable')
    rows = table.find_all('tr')
    res = []
    for row in rows[1:]:
        cols = row.find_all('td')
        stage = {
            'Stage': cols[0].text.strip(),
            # 'Highlights': cols[1].text.strip(),
            'Date': cols[2].text.strip(),
            'Start': cols[3].text.strip(),
            'Finish': cols[4].text.strip()
        }
        res.append(stage)
    return res

def get_jersey_wearers_data(data_url):
    data_html = get_html(data_url)
    data_soup = BeautifulSoup(data_html, 'html.parser')
    
    # Get the table with class 'rankingTable'
    table = data_soup.find('table', class_='rankingTable')
    rows = table.find_all('tr')
    res = []
    for row in rows[1:]:
        cols = row.find_all('td')
        stage = {
            'Stage': cols[0].text.strip(),
            'Yellow Jersey': cols[1].text.strip(),
            'Green Jersey': cols[2].text.strip(),
            'Polka Dot Jersey': cols[3].text.strip(),
            'White Jersey': cols[4].text.strip()
        }
        res.append(stage)
    return res

def get_stage_winners_data(data_url):
    data_html = get_html(data_url)
    data_soup = BeautifulSoup(data_html, 'html.parser')
    
    # Get the table with class 'rankingTable'
    table = data_soup.find('table', class_='rankingTable')
    rows = table.find_all('tr')
    res = []
    for row in rows[1:]:
        cols = row.find_all('td')
        stage = {
            'Stage': cols[0].text.strip(),
            'Parcours': cols[2].text.strip(),
            'Winner of stage': cols[3].text.strip().split('\n')[0],
        }
        res.append(stage)
    return res

year = "2002"
teams = get_teams_data(selections_urls[year]["Starters"])
print("Teams:", teams)
stages = get_stages_data(selections_urls[year]["Stages"])
print("Stages:", stages)
jersey_wearers = get_jersey_wearers_data(selections_urls[year]["Jersey wearers"])
print("Jersey Wearers:", jersey_wearers)
stage_winners = get_stage_winners_data(selections_urls[year]["Stages winners"])
print("Stage Winners:", stage_winners)
# Out:
# Teams: {'US POSTAL SERVICE': [{'bib': '1', 'name': 'LANCE ARMSTRONG'}, {'bib': '2', 'name': 'VJATCESLAV EKIMOV'}, {'bib': '3', 'name': 'ROBERTO HERAS'}, {'bib': '4', 'name': 'GEORGE HINCAPIE'}, {'bib': '5', 'name': 'BENOIT JOACHIM'}, {'bib': '6', 'name': 'FLOYD LANDIS'}, {'bib': '7', 'name': 'PAVEL PADRNOS'}, {'bib': '8', 'name': 'VICTOR HUGO PENA'}, {'bib': '9', 'name': 'JOSÉ LUIS RUBIERA'}], 'TEAM TELEKOM': [{'bib': '11', 'name': 'ERIK ZABEL'}, {'bib': '12', 'name': 'ROLF ALDAG'}, {'bib': '13', 'name': 'UDO BÖLTS'}, {'bib': '14', 'name': 'GIAN MATTEO FAGNINI'}, {'bib': '15', 'name': 'GIUSEPPE GUERINI'}, {'bib': '16', 'name': 'DANILO HONDO'}, {'bib': '17', 'name': 'BOBBY JULICH'}, {'bib': '18', 'name': 'KEVIN LIVINGSTON'}, {'bib': '19', 'name': 'STEFFEN WESEMANN'}], 'ONCE - EROSKI': [{'bib': '21', 'name': 'JOSEBA BELOKI'}, {'bib': '22', 'name': 'JOSÉ AZEVEDO'}, {'bib': '23', 'name': 'ALVARO GONZALEZ GALDEANO'}, {'bib': '24', 'name': 'IGOR GONZALEZ GALDEANO'}, {'bib': '25', 'name': 'JÖRG JAKSCHE'}, {'bib': '26', 'name': 'ISIDRO NOZAL'}, {'bib': '27', 'name': 'ABRAHAM OLANO'}, {'bib': '28', 'name': 'MIKEL PRADERA'}, {'bib': '29', 'name': 'MARCOS ANTONIO SERRANO RODRIGUEZ'}], 'KELME - COSTA BLANCA': [{'bib': '31', 'name': 'OSCAR SEVILLA'}, {'bib': '32', 'name': 'SANTIAGO BOTERO'}, {'bib': '33', 'name': 'FRANCISCO CABELLO'}, {'bib': '34', 'name': 'JOSÉ-JAVIER GOMEZ'}, {'bib': '35', 'name': 'JOSÉ ENRIQUE GUTIERREZ'}, {'bib': '36', 'name': 'SANTIAGO PEREZ'}, {'bib': '37', 'name': 'TONI TAULER'}, {'bib': '38', 'name': 'JOSÉ ANGEL VIDAL'}, {'bib': '39', 'name': 'CONSTANTINO ZABALLA'}], 'COFIDIS CREDIT PAR TELEPHONE': [{'bib': '41', 'name': 'ANDREI KIVILEV'}, {'bib': '42', 'name': 'DANIEL ATIENZA'}, {'bib': '43', 'name': 'INIGO CUESTA'}, {'bib': '44', 'name': 'BINGEN FERNANDEZ'}, {'bib': '45', 'name': 'MASSIMILIANO LELLI'}, {'bib': '46', 'name': 'NICO MATTAN'}, {'bib': '47', 'name': 'DAVID MILLAR'}, {'bib': '48', 'name': 'DAVID MONCOUTIE'}, {'bib': '49', 'name': 'CÉDRIC VASSEUR'}], 'TEAM CSC TISCALI': [{'bib': '51', 'name': 'LAURENT JALABERT'}, {'bib': '52', 'name': 'TYLER HAMILTON'}, {'bib': '53', 'name': 'ANDREA PERON'}, {'bib': '54', 'name': 'JAKOB PIIL'}, {'bib': '55', 'name': 'ARVIS PIZIKS'}, {'bib': '56', 'name': 'MICHAEL SANDSTOD'}, {'bib': '57', 'name': 'CARLOS SASTRE'}, {'bib': '58', 'name': 'NICKI SORENSEN'}, {'bib': '59', 'name': 'PAUL VAN HYFTE'}], 'CREDIT AGRICOLE': [{'bib': '61', 'name': 'CHRISTOPHE MOREAU'}, {'bib': '62', 'name': 'FRÉDÉRIC BESSY'}, {'bib': '63', 'name': 'SÉBASTIEN HINAULT'}, {'bib': '64', 'name': 'THOR HUSHOVD'}, {'bib': '65', 'name': 'ANTHONY LANGELLA'}, {'bib': '66', 'name': 'ANTHONY MORIN'}, {'bib': '67', 'name': "STUART O'GRADY"}, {'bib': '68', 'name': 'JONATHAN VAUGHTERS'}, {'bib': '69', 'name': 'JENS VOIGT'}], 'DOMO - FARM FRITES': [{'bib': '71', 'name': 'RICHARD VIRENQUE'}, {'bib': '72', 'name': 'DAVE BRUYLANDTS'}, {'bib': '73', 'name': 'ENRICO CASSANI'}, {'bib': '74', 'name': 'SERVAIS KNAVEN'}, {'bib': '75', 'name': 'TOMAS KONECNY'}, {'bib': '76', 'name': 'AXEL MERCKX'}, {'bib': '77', 'name': 'FRED RODRIGUEZ'}, {'bib': '78', 'name': 'LEON VAN BON'}, {'bib': '79', 'name': 'PIOTR WADECKI'}], 'FASSA BORTOLO': [{'bib': '81', 'name': 'IVAN BASSO'}, {'bib': '82', 'name': 'FABIO BALDATO'}, {'bib': '83', 'name': 'WLADIMIR BELLI'}, {'bib': '84', 'name': 'VOLODYMIR GUSTOV'}, {'bib': '85', 'name': 'SERHIY HONCHAR'}, {'bib': '86', 'name': 'SERGUEI IVANOV'}, {'bib': '87', 'name': 'NICOLA LODA'}, {'bib': '88', 'name': 'OSCAR POZZI'}, {'bib': '89', 'name': 'MARCO VELO'}], 'FDJeux.com': [{'bib': '91', 'name': 'NICOLAS VOGONDY'}, {'bib': '92', 'name': 'SANDY CASAR'}, {'bib': '93', 'name': 'JIMMY CASPER'}, {'bib': '94', 'name': 'BADEN COOKE'}, {'bib': '95', 'name': 'JACKY DURAND'}, {'bib': '96', 'name': 'FRÉDÉRIC GUESDON'}, {'bib': '97', 'name': 'BRADLEY MC GEE'}, {'bib': '98', 'name': 'CHRISTOPHE MENGIN'}, {'bib': '99', 'name': 'JEAN-CYRIL ROBIN'}], 'RABOBANK': [{'bib': '101', 'name': 'LEVI LEIPHEIMER'}, {'bib': ...
# Stages: [{'Stage': 'Prologue', 'Date': '06/07/2002', 'Start': 'Luxembourg', 'Finish': 'Luxembourg'}, {'Stage': 'Stage 1', 'Date': '07/07/2002', 'Start': 'Luxembourg', 'Finish': 'Luxembourg'}, {'Stage': 'Stage 2', 'Date': '08/07/2002', 'Start': 'Luxembourg', 'Finish': 'Sarrebruck'}, {'Stage': 'Stage 3', 'Date': '09/07/2002', 'Start': 'Metz', 'Finish': 'Reims'}, {'Stage': 'Stage 4', 'Date': '10/07/2002', 'Start': 'Épernay', 'Finish': 'Château-Thierry'}, {'Stage': 'Stage 5', 'Date': '11/07/2002', 'Start': 'Soissons', 'Finish': 'Rouen'}, {'Stage': 'Stage 6', 'Date': '12/07/2002', 'Start': 'Forges-les-Eaux', 'Finish': 'Alençon'}, {'Stage': 'Stage 7', 'Date': '12/07/2002', 'Start': "Bagnoles-de-l'Orne", 'Finish': 'Avranches'}, {'Stage': 'Stage 8', 'Date': '14/07/2002', 'Start': 'Saint-Martin-de-Landelles', 'Finish': 'Plouay'}, {'Stage': 'Stage 9', 'Date': '15/07/2002', 'Start': 'Lanester', 'Finish': 'Lorient'}, {'Stage': 'Stage 10', 'Date': '17/07/2002', 'Start': 'Bazas', 'Finish': 'Pau'}, {'Stage': 'Stage 11', 'Date': '18/07/2002', 'Start': 'Pau', 'Finish': 'La Mongie'}, {'Stage': 'Stage 12', 'Date': '19/07/2002', 'Start': 'Lannemezan', 'Finish': 'plateau_de_beille'}, {'Stage': 'Stage 13', 'Date': '20/07/2002', 'Start': 'Lavelanet', 'Finish': 'Béziers'}, {'Stage': 'Stage 14', 'Date': '21/07/2002', 'Start': 'Lodève', 'Finish': 'Mont Ventoux'}, {'Stage': 'Stage 15', 'Date': '23/07/2002', 'Start': 'Vaison-la-Romaine', 'Finish': 'Les Deux Alpes'}, {'Stage': 'Stage 16', 'Date': '24/07/2002', 'Start': 'Les Deux Alpes', 'Finish': 'La Plagne'}, {'Stage': 'Stage 17', 'Date': '25/07/2002', 'Start': 'Aime', 'Finish': 'Cluses'}, {'Stage': 'Stage 18', 'Date': '26/07/2002', 'Start': 'Cluses', 'Finish': 'Bourg-en-Bresse'}, {'Stage': 'Stage 19', 'Date': '27/07/2002', 'Start': 'Regnier-Durette', 'Finish': 'Macon'}, {'Stage': 'Stage 20', 'Date': '28/07/2002', 'Start': 'Melun', 'Finish': 'Paris'}]
# Jersey Wearers: [{'Stage': '0', 'Yellow Jersey': '', 'Green Jersey': 'LAURENT JALABERT', 'Polka Dot Jersey': '', 'White Jersey': 'DAVID MILLAR'}, {'Stage': '1', 'Yellow Jersey': 'RUBENS BERTOGLIATI', 'Green Jersey': 'ERIK ZABEL', 'Polka Dot Jersey': 'CHRISTOPHE MENGIN', 'White Jersey': 'RUBENS BERTOGLIATI'}, {'Stage': '2', 'Yellow Jersey': 'RUBENS BERTOGLIATI', 'Green Jersey': 'ERIK ZABEL', 'Polka Dot Jersey': 'STÃ‰PHANE BERGES', 'White Jersey': 'RUBENS BERTOGLIATI'}, {'Stage': '3', 'Yellow Jersey': 'ERIK ZABEL', 'Green Jersey': 'ERIK ZABEL', 'Polka Dot Jersey': 'CHRISTOPHE MENGIN', 'White Jersey': 'RUBENS BERTOGLIATI'}, {'Stage': '4', 'Yellow Jersey': 'IGOR GONZALEZ GALDEANO', 'Green Jersey': 'ERIK ZABEL', 'Polka Dot Jersey': 'CHRISTOPHE MENGIN', 'White Jersey': 'ISIDRO NOZAL'}, {'Stage': '5', 'Yellow Jersey': 'IGOR GONZALEZ GALDEANO', 'Green Jersey': 'ERIK ZABEL', 'Polka Dot Jersey': 'CHRISTOPHE MENGIN', 'White Jersey': 'ISIDRO NOZAL'}, {'Stage': '6', 'Yellow Jersey': 'IGOR GONZALEZ GALDEANO', 'Green Jersey': 'ERIK ZABEL', 'Polka Dot Jersey': 'CHRISTOPHE MENGIN', 'White Jersey': 'ISIDRO NOZAL'}, {'Stage': '7', 'Yellow Jersey': 'IGOR GONZALEZ GALDEANO', 'Green Jersey': 'ERIK ZABEL', 'Polka Dot Jersey': 'CHRISTOPHE MENGIN', 'White Jersey': 'ISIDRO NOZAL'}, {'Stage': '8', 'Yellow Jersey': 'IGOR GONZALEZ GALDEANO', 'Green Jersey': 'ERIK ZABEL', 'Polka Dot Jersey': 'CHRISTOPHE MENGIN', 'White Jersey': 'ISIDRO NOZAL'}, {'Stage': '9', 'Yellow Jersey': 'IGOR GONZALEZ GALDEANO', 'Green Jersey': 'ERIK ZABEL', 'Polka Dot Jersey': 'CHRISTOPHE MENGIN', 'White Jersey': 'DAVID MILLAR'}, {'Stage': '10', 'Yellow Jersey': 'IGOR GONZALEZ GALDEANO', 'Green Jersey': 'ROBBIE MC EWEN', 'Polka Dot Jersey': 'CHRISTOPHE MENGIN', 'White Jersey': 'DAVID MILLAR'}, {'Stage': '11', 'Yellow Jersey': '', 'Green Jersey': 'ERIK ZABEL', 'Polka Dot Jersey': 'PATRICE HALGAND', 'White Jersey': 'IVAN BASSO'}, {'Stage': '12', 'Yellow Jersey': '', 'Green Jersey': 'ERIK ZABEL', 'Polka Dot Jersey': 'LAURENT JALABERT', 'White Jersey': 'IVAN BASSO'}, {'Stage': '13', 'Yellow Jersey': '', 'Green Jersey': 'ROBBIE MC EWEN', 'Polka Dot Jersey': 'LAURENT JALABERT', 'White Jersey': 'IVAN BASSO'}, {'Stage': '14', 'Yellow Jersey': '', 'Green Jersey': 'ROBBIE MC EWEN', 'Polka Dot Jersey': 'LAURENT JALABERT', 'White Jersey': 'IVAN BASSO'}, {'Stage': '15', 'Yellow Jersey': '', 'Green Jersey': 'ROBBIE MC EWEN', 'Polka Dot Jersey': 'LAURENT JALABERT', 'White Jersey': 'IVAN BASSO'}, {'Stage': '16', 'Yellow Jersey': '', 'Green Jersey': 'ROBBIE MC EWEN', 'Polka Dot Jersey': 'LAURENT JALABERT', 'White Jersey': 'IVAN BASSO'}, {'Stage': '17', 'Yellow Jersey': '', 'Green Jersey': 'ROBBIE MC EWEN', 'Polka Dot Jersey': 'LAURENT JALABERT', 'White Jersey': 'IVAN BASSO'}, {'Stage': '18', 'Yellow Jersey': '', 'Green Jersey': 'ROBBIE MC EWEN', 'Polka Dot Jersey': 'LAURENT JALABERT', 'White Jersey': 'IVAN BASSO'}, {'Stage': '19', 'Yellow Jersey': '', 'Green Jersey': 'ROBBIE MC EWEN', 'Polka Dot Jersey': 'LAURENT JALABERT', 'White Jersey': 'IVAN BASSO'}, {'Stage': '20', 'Yellow Jersey': '', 'Green Jersey': 'ROBBIE MC EWEN', 'Polka Dot Jersey': 'LAURENT JALABERT', 'White Jersey': 'IVAN BASSO'}]
# Stage Winners: [{'Stage': '1', 'Parcours': 'Luxembourg > Luxembourg', 'Winner of stage': 'RUBENS BERTOGLIATI'}, {'Stage': '2', 'Parcours': 'Luxembourg > Sarrebruck', 'Winner of stage': 'OSCAR FREIRE'}, {'Stage': '3', 'Parcours': 'Metz > Reims', 'Winner of stage': 'ROBBIE MC EWEN'}, {'Stage': '4', 'Parcours': 'Épernay > Château-Thierry', 'Winner of stage': 'ONCE - EROSKI'}, {'Stage': '5', 'Parcours': 'Soissons > Rouen', 'Winner of stage': 'JAAN KIRSIPUU'}, {'Stage': '6', 'Parcours': 'Forges-les-Eaux > Alençon', 'Winner of stage': 'ERIK ZABEL'}, {'Stage': '7', 'Parcours': "Bagnoles-de-l'Orne > Avranches", 'Winner of stage': 'BRADLEY MC GEE'}, {'Stage': '8', 'Parcours': 'Saint-Martin-de-Landelles > Plouay', 'Winner of stage': 'KARSTEN KROON'}, {'Stage': '9', 'Parcours': 'Lanester > Lorient', 'Winner of stage': 'SANTIAGO BOTERO'}, {'Stage': '10', 'Parcours': 'Bazas > Pau', 'Winner of stage': 'PATRICE HALGAND'}, {'Stage': '13', 'Parcours': 'Lavelanet > Béziers', 'Winner of stage': 'DAVID MILLAR'}, {'Stage': '14', 'Parcours': 'Lodève > Mont Ventoux', 'Winner of stage': 'RICHARD VIRENQUE'}, {'Stage': '15', 'Parcours': 'Vaison-la-Romaine > Les Deux Alpes', 'Winner of stage': 'SANTIAGO BOTERO'}, {'Stage': '16', 'Parcours': 'Les Deux Alpes > La Plagne', 'Winner of stage': 'MICHAEL BOOGERD'}, {'Stage': '17', 'Parcours': 'Aime > Cluses', 'Winner of stage': 'DARIO FRIGO'}, {'Stage': '18', 'Parcours': 'Cluses > Bourg-en-Bresse', 'Winner of stage': 'THOR HUSHOVD'}, {'Stage': '20', 'Parcours': 'Melun > Paris', 'Winner of stage': 'ROBBIE MC EWEN'}]
